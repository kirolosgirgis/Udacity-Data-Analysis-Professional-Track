# %%
import pandas as pd
import wptools
import os
import requests
from PIL import Image
from io import BytesIO

# %%
title_list = [
 'The_Wizard_of_Oz_(1939_film)',
 'Citizen_Kane',
 'The_Third_Man',
 'Get_Out_(film)',
 'Mad_Max:_Fury_Road',
 'The_Cabinet_of_Dr._Caligari',
 'All_About_Eve',
 'Inside_Out_(2015_film)',
 'The_Godfather',
 'Metropolis_(1927_film)',
 'E.T._the_Extra-Terrestrial',
 'Modern_Times_(film)',
 'It_Happened_One_Night',
 "Singin'_in_the_Rain",
 'Boyhood_(film)',
 'Casablanca_(film)',
 'Moonlight_(2016_film)',
 'Psycho_(1960_film)',
 'Laura_(1944_film)',
 'Nosferatu',
 'Snow_White_and_the_Seven_Dwarfs_(1937_film)',
 "A_Hard_Day%27s_Night_(film)",
 'La_Grande_Illusion',
 'North_by_Northwest',
 'The_Battle_of_Algiers',
 'Dunkirk_(2017_film)',
 'The_Maltese_Falcon_(1941_film)',
 'Repulsion_(film)',
 '12_Years_a_Slave_(film)',
 'Gravity_(2013_film)',
 'Sunset_Boulevard_(film)',
 'King_Kong_(1933_film)',
 'Spotlight_(film)',
 'The_Adventures_of_Robin_Hood',
 'Rashomon',
 'Rear_Window',
 'Selma_(film)',
 'Taxi_Driver',
 'Toy_Story_3',
 'Argo_(2012_film)',
 'Toy_Story_2',
 'The_Big_Sick',
 'Bride_of_Frankenstein',
 'Zootopia',
 'M_(1931_film)',
 'Wonder_Woman_(2017_film)',
 'The_Philadelphia_Story_(film)',
 'Alien_(film)',
 'Bicycle_Thieves',
 'Seven_Samurai',
 'The_Treasure_of_the_Sierra_Madre_(film)',
 'Up_(2009_film)',
 '12_Angry_Men_(1957_film)',
 'The_400_Blows',
 'Logan_(film)',
 'All_Quiet_on_the_Western_Front_(1930_film)',
 'Army_of_Shadows',
 'Arrival_(film)',
 'Baby_Driver',
 'A_Streetcar_Named_Desire_(1951_film)',
 'The_Night_of_the_Hunter_(film)',
 'Star_Wars:_The_Force_Awakens',
 'Manchester_by_the_Sea_(film)',
 'Dr._Strangelove',
 'Frankenstein_(1931_film)',
 'Vertigo_(film)',
 'The_Dark_Knight_(film)',
 'Touch_of_Evil',
 'The_Babadook',
 'The_Conformist_(film)',
 'Rebecca_(1940_film)',
 "Rosemary%27s_Baby_(film)",
 'Finding_Nemo',
 'Brooklyn_(film)',
 'The_Wrestler_(2008_film)',
 'The_39_Steps_(1935_film)',
 'L.A._Confidential_(film)',
 'Gone_with_the_Wind_(film)',
 'The_Good,_the_Bad_and_the_Ugly',
 'Skyfall',
 'Rome,_Open_City',
 'Tokyo_Story',
 'Hell_or_High_Water_(film)',
 'Pinocchio_(1940_film)',
 'The_Jungle_Book_(2016_film)',
 'La_La_Land_(film)',
 'Star_Trek_(film)',
 'High_Noon',
 'Apocalypse_Now',
 'On_the_Waterfront',
 'The_Wages_of_Fear',
 'The_Last_Picture_Show',
 'Harry_Potter_and_the_Deathly_Hallows_–_Part_2',
 'The_Grapes_of_Wrath_(film)',
 'Roman_Holiday',
 'Man_on_Wire',
 'Jaws_(film)',
 'Toy_Story',
 'The_Godfather_Part_II',
 'Battleship_Potemkin'
]

# %%
folder_name = 'bestofrt_posters'
# Make directory if it doesn't already exist
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# %%
# List of dictionaries to build and convert to a DataFrame later
df_list = []
image_errors = {}
for title in title_list:
    try:
        # This cell is slow so print ranking to gauge time remaining
        ranking = title_list.index(title) + 1
        print(ranking)
        page = wptools.page(title, silent=True)
        # Your code here (three lines)
        images = page.get().data['image']
        # First image is usually the poster
        first_image_url = images[0]['url']
        print(first_image_url)
        r = requests.get(first_image_url)
        # Download movie poster image
        i = Image.open(BytesIO(r.content))
        image_file_format = first_image_url.split('.')[-1]
        i.save(folder_name + "/" + str(ranking) + "_" + title + '.' + image_file_format)
        # Append to list of dictionaries
        df_list.append({'ranking': int(ranking),
                        'title': title,
                        'poster_url': first_image_url})
    
    # Not best practice to catch all exceptions but fine for this short script
    except Exception as e:
        print(str(ranking) + "_" + title + ": " + str(e))
        image_errors[str(ranking) + "_" + title] = images
# Out:
# 1
# https://upload.wikimedia.org/wikipedia/commons/6/69/Wizard_of_oz_movie_poster.jpg
# 2
# https://upload.wikimedia.org/wikipedia/commons/c/c0/Citizen_Kane_poster%2C_1941_%28Style_B%2C_unrestored%29.jpg
# 2_Citizen_Kane: cannot identify image file <_io.BytesIO object at 0x0000025D424D39F0>
# 3
# https://upload.wikimedia.org/wikipedia/commons/7/77/The_Third_Man_%281949_American_theatrical_poster%29.jpg
# 3_The_Third_Man: cannot identify image file <_io.BytesIO object at 0x0000025D437CF770>
# 4
# https://upload.wikimedia.org/wikipedia/en/a/a3/Get_Out_poster.png
# 5
# https://upload.wikimedia.org/wikipedia/en/6/6e/Mad_Max_Fury_Road.jpg
# 6
# https://upload.wikimedia.org/wikipedia/en/2/2f/The_Cabinet_of_Dr._Caligari_poster.jpg
# 6_The_Cabinet_of_Dr._Caligari: cannot identify image file <_io.BytesIO object at 0x0000025D437B9B80>
# 7
# https://upload.wikimedia.org/wikipedia/commons/a/a7/All_About_Eve_%281950_poster_-_retouch%29.jpg
# 7_All_About_Eve: cannot identify image file <_io.BytesIO object at 0x0000025D437BC8B0>
# 8
# https://upload.wikimedia.org/wikipedia/en/0/0a/Inside_Out_%282015_film%29_poster.jpg
# 9
# https://upload.wikimedia.org/wikipedia/en/1/1c/Godfather_ver1.jpg
# 10
# https://upload.wikimedia.org/wikipedia/commons/8/83/Metropolis1927-logo.svg
# 10_Metropolis_(1927_film): cannot identify image file <_io.BytesIO object at 0x0000025D437B9720>
# 11
# https://upload.wikimedia.org/wikipedia/en/6/66/E_t_the_extra_terrestrial_ver3.jpg
# 12
# https://upload.wikimedia.org/wikipedia/commons/3/36/Modern_Times_poster.jpg
# 13
# https://upload.wikimedia.org/wikipedia/commons/d/dc/It-happened-one-night-poster.jpg
# 13_It_Happened_One_Night: cannot identify image file <_io.BytesIO object at 0x0000025D41447900>
# 14
# https://upload.wikimedia.org/wikipedia/commons/5/5d/Singin%27_in_the_Rain_%281952_poster%29.jpg
# 15
# 15_Boyhood_(film): 'image'
# 16
# https://upload.wikimedia.org/wikipedia/commons/b/b3/CasablancaPoster-Gold.jpg
# 17
# https://upload.wikimedia.org/wikipedia/en/8/84/Moonlight_%282016_film%29.png
# 18
# https://upload.wikimedia.org/wikipedia/commons/7/76/Psycho_%281960%29_theatrical_poster_%28retouched%29.jpg
# 18_Psycho_(1960_film): cannot identify image file <_io.BytesIO object at 0x0000025D437DC450>
# 19
# https://upload.wikimedia.org/wikipedia/commons/3/30/Laura_%281944_film_poster%29.jpg
# 19_Laura_(1944_film): cannot identify image file <_io.BytesIO object at 0x0000025D437A0310>
# 20
# https://upload.wikimedia.org/wikipedia/en/9/92/Nosferatuposter.jpg
# 21
# https://upload.wikimedia.org/wikipedia/en/4/49/Snow_White_1937_poster.png
# 22
# API error: {'code': 'invalidtitle', 'info': 'Bad title "A_Hard_Day%27s_Night_(film)".', 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 22_A_Hard_Day%27s_Night_(film): https://en.wikipedia.org/w/api.php?action=parse&formatversion=2&contentmodel=text&disableeditsection=&disablelimitreport=&disabletoc=&prop=text|iwlinks|parsetree|wikitext|displaytitle|properties&redirects&page=A_Hard_Day%2527s_Night_%28film%29
# 23
# https://upload.wikimedia.org/wikipedia/en/3/33/GrandeIllusion.jpg
# 23_La_Grande_Illusion: cannot identify image file <_io.BytesIO object at 0x0000025D4263A040>
# 24
# https://upload.wikimedia.org/wikipedia/commons/8/83/Northbynorthwest1.jpg
# 24_North_by_Northwest: cannot identify image file <_io.BytesIO object at 0x0000025D43744AE0>
# 25
# https://upload.wikimedia.org/wikipedia/en/a/aa/The_Battle_of_Algiers_poster.jpg
# 26
# https://upload.wikimedia.org/wikipedia/en/1/15/Dunkirk_Film_poster.jpg
# 27
# https://upload.wikimedia.org/wikipedia/commons/6/6b/The_Maltese_Falcon_%281941_film_poster%29.jpg
# 27_The_Maltese_Falcon_(1941_film): cannot identify image file <_io.BytesIO object at 0x0000025D41359D60>
# 28
# https://upload.wikimedia.org/wikipedia/en/8/89/Repulsion_%281965_film_poster%29.jpg
# 28_Repulsion_(film): cannot identify image file <_io.BytesIO object at 0x0000025D41369C20>
# 29
# https://upload.wikimedia.org/wikipedia/en/5/5c/12_Years_a_Slave_film_poster.jpg
# 30
# https://upload.wikimedia.org/wikipedia/en/f/f6/Gravity_Poster.jpg
# 31
# https://upload.wikimedia.org/wikipedia/commons/1/14/Sunset_Boulevard_%281950_poster%29.jpg
# 32
# https://upload.wikimedia.org/wikipedia/commons/f/f3/Kingkongposter.jpg
# 32_King_Kong_(1933_film): cannot identify image file <_io.BytesIO object at 0x0000025D437B1680>
# 33
# https://upload.wikimedia.org/wikipedia/en/f/f3/Spotlight_%28film%29_poster.jpg
# 34
# https://upload.wikimedia.org/wikipedia/commons/f/f7/The_Adventures_of_Robin_Hood_%281938_poster%29.jpg
# 34_The_Adventures_of_Robin_Hood: cannot identify image file <_io.BytesIO object at 0x0000025D42672630>
# 35
# https://upload.wikimedia.org/wikipedia/commons/a/a3/Rashomon_poster_3.jpg
# 35_Rashomon: cannot identify image file <_io.BytesIO object at 0x0000025D437E2310>
# 36
# https://upload.wikimedia.org/wikipedia/commons/3/38/Rear_Window_film_poster.jpg
# 36_Rear_Window: cannot identify image file <_io.BytesIO object at 0x0000025D437DC2C0>
# 37
# https://upload.wikimedia.org/wikipedia/en/8/8f/Selma_poster.jpg
# 38
# https://upload.wikimedia.org/wikipedia/en/3/33/Taxi_Driver_%281976_film_poster%29.jpg
# 39
# https://upload.wikimedia.org/wikipedia/en/6/69/Toy_Story_3_poster.jpg
# 40
# https://upload.wikimedia.org/wikipedia/en/e/e1/Argo2012Poster.jpg
# 41
# https://upload.wikimedia.org/wikipedia/en/c/c0/Toy_Story_2.jpg
# 42
# https://upload.wikimedia.org/wikipedia/en/6/69/The_Big_Sick.jpg
# 43
# https://upload.wikimedia.org/wikipedia/commons/5/58/The_Bride_of_Frankenstein_%281935_poster%29.jpg
# 43_Bride_of_Frankenstein: cannot identify image file <_io.BytesIO object at 0x0000025D437BC220>
# 44
# https://upload.wikimedia.org/wikipedia/en/9/96/Zootopia_%28movie_poster%29.jpg
# 45
# https://upload.wikimedia.org/wikipedia/en/a/ab/M_poster.jpg
# 46
# https://upload.wikimedia.org/wikipedia/en/b/b0/Wonder_Woman_%282017_film%29_poster.jpg
# 47
# https://upload.wikimedia.org/wikipedia/commons/5/54/The-Philadelphia-Story-%281940%29.jpg
# 47_The_Philadelphia_Story_(film): cannot identify image file <_io.BytesIO object at 0x0000025D424DB400>
# 48
# https://upload.wikimedia.org/wikipedia/en/c/c3/Alien_movie_poster.jpg
# 49
# https://upload.wikimedia.org/wikipedia/en/2/20/Ladri3.jpg
# 50
# https://upload.wikimedia.org/wikipedia/commons/b/ba/Seven_Samurai_poster.jpg
# 50_Seven_Samurai: cannot identify image file <_io.BytesIO object at 0x0000025D437BC220>
# 51
# https://upload.wikimedia.org/wikipedia/commons/1/1d/The_Treasure_of_the_Sierra_Madre_%281947_poster%29.jpg
# 51_The_Treasure_of_the_Sierra_Madre_(film): cannot identify image file <_io.BytesIO object at 0x0000025D437B2360>
# 52
# https://upload.wikimedia.org/wikipedia/en/0/05/Up_%282009_film%29.jpg
# 53
# https://upload.wikimedia.org/wikipedia/commons/b/b5/12_Angry_Men_%281957_film_poster%29.jpg
# 53_12_Angry_Men_(1957_film): cannot identify image file <_io.BytesIO object at 0x0000025D436BFA90>
# 54
# https://upload.wikimedia.org/wikipedia/en/f/f9/Quatre_coups2.jpg
# 54_The_400_Blows: cannot identify image file <_io.BytesIO object at 0x0000025D437CAF90>
# 55
# https://upload.wikimedia.org/wikipedia/en/3/37/Logan_2017_poster.jpg
# 56
# https://upload.wikimedia.org/wikipedia/commons/6/6c/All_Quiet_on_the_Western_Front_%281930_film%29_poster.jpg
# 56_All_Quiet_on_the_Western_Front_(1930_film): cannot identify image file <_io.BytesIO object at 0x0000025D41359D60>
# 57
# https://upload.wikimedia.org/wikipedia/en/0/08/ARMY_OF_SHADOWS_1SH.jpg
# 57_Army_of_Shadows: cannot identify image file <_io.BytesIO object at 0x0000025D4136D3B0>
# 58
# https://upload.wikimedia.org/wikipedia/en/d/df/Arrival%2C_Movie_Poster.jpg
# 59
# https://upload.wikimedia.org/wikipedia/en/8/8e/Baby_Driver_poster.jpg
# 60
# https://upload.wikimedia.org/wikipedia/commons/f/fe/A_Streetcar_Named_Desire_%281951%29.jpg
# 60_A_Streetcar_Named_Desire_(1951_film): cannot identify image file <_io.BytesIO object at 0x0000025D41369AE0>
# 61
# https://upload.wikimedia.org/wikipedia/commons/a/a5/The_Night_of_the_Hunter_%281955_poster%29.jpg
# 61_The_Night_of_the_Hunter_(film): cannot identify image file <_io.BytesIO object at 0x0000025D41359D60>
# 62
# https://upload.wikimedia.org/wikipedia/en/a/a2/Star_Wars_The_Force_Awakens_Theatrical_Poster.jpg
# 63
# https://upload.wikimedia.org/wikipedia/en/d/de/Manchester_by_the_Sea.jpg
# 64
# https://upload.wikimedia.org/wikipedia/en/e/e6/Dr._Strangelove_poster.jpg
# 65
# https://upload.wikimedia.org/wikipedia/commons/9/92/Frankenstein_poster_1931.jpg
# 65_Frankenstein_(1931_film): cannot identify image file <_io.BytesIO object at 0x0000025D43744A90>
# 66
# https://upload.wikimedia.org/wikipedia/commons/7/75/Vertigomovie_restoration.jpg
# 66_Vertigo_(film): cannot identify image file <_io.BytesIO object at 0x0000025D437A2EF0>
# 67
# https://upload.wikimedia.org/wikipedia/en/1/1c/The_Dark_Knight_%282008_film%29.jpg
# 68
# https://upload.wikimedia.org/wikipedia/commons/0/09/Touch_of_Evil_%281958_poster%29.jpg
# 68_Touch_of_Evil: cannot identify image file <_io.BytesIO object at 0x0000025D43A0CF90>
# 69
# https://upload.wikimedia.org/wikipedia/en/d/d7/The-Babadook-Poster.jpg
# 70
# https://upload.wikimedia.org/wikipedia/en/7/78/The_Conformist_poster.jpg
# 70_The_Conformist_(film): cannot identify image file <_io.BytesIO object at 0x0000025D425A46D0>
# 71
# https://upload.wikimedia.org/wikipedia/commons/a/ad/Rebecca_%281939_poster%29.jpeg
# 71_Rebecca_(1940_film): cannot identify image file <_io.BytesIO object at 0x0000025D43751B80>
# 72
# API error: {'code': 'invalidtitle', 'info': 'Bad title "Rosemary%27s_Baby_(film)".', 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 72_Rosemary%27s_Baby_(film): https://en.wikipedia.org/w/api.php?action=parse&formatversion=2&contentmodel=text&disableeditsection=&disablelimitreport=&disabletoc=&prop=text|iwlinks|parsetree|wikitext|displaytitle|properties&redirects&page=Rosemary%2527s_Baby_%28film%29
# 73
# https://upload.wikimedia.org/wikipedia/en/2/29/Finding_Nemo.jpg
# 74
# https://upload.wikimedia.org/wikipedia/en/5/5b/Brooklyn_FilmPoster.jpg
# 75
# https://upload.wikimedia.org/wikipedia/en/3/3e/The_Wrestler_poster.jpg
# 76
# https://upload.wikimedia.org/wikipedia/en/f/ff/The_39_Steps_%28quad_poster%29.jpg
# 77
# https://upload.wikimedia.org/wikipedia/en/d/d8/La_confidential.jpg
# 78
# https://upload.wikimedia.org/wikipedia/commons/2/27/Poster_-_Gone_With_the_Wind_01.jpg
# 78_Gone_with_the_Wind_(film): cannot identify image file <_io.BytesIO object at 0x0000025D438B9270>
# 79
# https://upload.wikimedia.org/wikipedia/en/4/45/Good_the_bad_and_the_ugly_poster.jpg
# 80
# https://upload.wikimedia.org/wikipedia/en/a/a7/Skyfall_poster.jpg
# 81
# https://upload.wikimedia.org/wikipedia/en/1/19/Open_City_DVD.jpg
# 81_Rome,_Open_City: cannot identify image file <_io.BytesIO object at 0x0000025D437B27C0>
# 82
# https://upload.wikimedia.org/wikipedia/commons/1/1b/Tokyo-story-20201121.jpg
# 82_Tokyo_Story: cannot identify image file <_io.BytesIO object at 0x0000025D4378E6D0>
# 83
# https://upload.wikimedia.org/wikipedia/en/8/8f/Hell_or_High_Water_film_poster.png
# 83_Hell_or_High_Water_(film): cannot identify image file <_io.BytesIO object at 0x0000025D4319FAE0>
# 84
# https://upload.wikimedia.org/wikipedia/en/b/ba/Pinocchio-1940-poster.jpg
# 85
# https://upload.wikimedia.org/wikipedia/en/a/a4/The_Jungle_Book_%282016%29.jpg
# 86
# https://upload.wikimedia.org/wikipedia/en/a/ab/La_La_Land_%28film%29.png
# 87
# https://upload.wikimedia.org/wikipedia/en/2/29/Startrekposter.jpg
# 88
# https://upload.wikimedia.org/wikipedia/commons/8/81/High_Noon_%281952_poster%29.jpg
# 88_High_Noon: cannot identify image file <_io.BytesIO object at 0x0000025D4136DB30>
# 89
# https://upload.wikimedia.org/wikipedia/en/c/c2/Apocalypse_Now_poster.jpg
# 90
# https://upload.wikimedia.org/wikipedia/commons/e/ee/On_the_Waterfront_%281954_poster%29.jpg
# 90_On_the_Waterfront: cannot identify image file <_io.BytesIO object at 0x0000025D43792360>
# 91
# https://upload.wikimedia.org/wikipedia/en/f/f4/SalairedelapeurR350.jpg
# 91_The_Wages_of_Fear: cannot identify image file <_io.BytesIO object at 0x0000025D438BBC20>
# 92
# https://upload.wikimedia.org/wikipedia/en/8/8f/The_Last_Picture_Show_%28movie_poster%29.jpg
# 92_The_Last_Picture_Show: cannot identify image file <_io.BytesIO object at 0x0000025D42515130>
# 93
# https://upload.wikimedia.org/wikipedia/en/d/df/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2.jpg
# 94
# https://upload.wikimedia.org/wikipedia/commons/c/c1/The_Grapes_of_Wrath_%281940_poster%29.jpg
# 94_The_Grapes_of_Wrath_(film): cannot identify image file <_io.BytesIO object at 0x0000025D42515130>
# 95
# https://upload.wikimedia.org/wikipedia/commons/d/d0/Roman_Holiday_%281953_poster%29.jpg
# 95_Roman_Holiday: cannot identify image file <_io.BytesIO object at 0x0000025D4319FD60>
# 96
# https://upload.wikimedia.org/wikipedia/en/5/54/Man_on_wire_ver2.jpg
# 97
# https://upload.wikimedia.org/wikipedia/en/e/eb/JAWS_Movie_poster.jpg
# 98
# https://upload.wikimedia.org/wikipedia/en/1/13/Toy_Story.jpg
# 99
# https://upload.wikimedia.org/wikipedia/en/0/03/Godfather_part_ii.jpg
# 100
# https://upload.wikimedia.org/wikipedia/commons/8/85/Vintage_Potemkin.jpg
# 100_Battleship_Potemkin: cannot identify image file <_io.BytesIO object at 0x0000025D4141E270>

# %%
for key in image_errors.keys():
    print(key)
# Out:
# 2_Citizen_Kane
# 3_The_Third_Man
# 6_The_Cabinet_of_Dr._Caligari
# 7_All_About_Eve
# 10_Metropolis_(1927_film)
# 13_It_Happened_One_Night
# 15_Boyhood_(film)
# 18_Psycho_(1960_film)
# 19_Laura_(1944_film)
# 22_A_Hard_Day%27s_Night_(film)
# 23_La_Grande_Illusion
# 24_North_by_Northwest
# 27_The_Maltese_Falcon_(1941_film)
# 28_Repulsion_(film)
# 32_King_Kong_(1933_film)
# 34_The_Adventures_of_Robin_Hood
# 35_Rashomon
# 36_Rear_Window
# 43_Bride_of_Frankenstein
# 47_The_Philadelphia_Story_(film)
# 50_Seven_Samurai
# 51_The_Treasure_of_the_Sierra_Madre_(film)
# 53_12_Angry_Men_(1957_film)
# 54_The_400_Blows
# 56_All_Quiet_on_the_Western_Front_(1930_film)
# 57_Army_of_Shadows
# 60_A_Streetcar_Named_Desire_(1951_film)
# 61_The_Night_of_the_Hunter_(film)
# 65_Frankenstein_(1931_film)
# 66_Vertigo_(film)
# 68_Touch_of_Evil
# 70_The_Conformist_(film)
# 71_Rebecca_(1940_film)
# 72_Rosemary%27s_Baby_(film)
# 78_Gone_with_the_Wind_(film)
# 81_Rome,_Open_City
# 82_Tokyo_Story
# 83_Hell_or_High_Water_(film)
# 88_High_Noon
# 90_On_the_Waterfront
# 91_The_Wages_of_Fear
# 92_The_Last_Picture_Show
# 94_The_Grapes_of_Wrath_(film)
# 95_Roman_Holiday
# 100_Battleship_Potemkin

# %%
# Inspect unidentifiable images and download them individually
for rank_title, images in image_errors.items():
    if rank_title == '22_A_Hard_Day%27s_Night_(film)':
        url = 'https://upload.wikimedia.org/wikipedia/en/4/47/A_Hard_Days_night_movieposter.jpg'
    if rank_title == '53_12_Angry_Men_(1957_film)':
        url = 'https://upload.wikimedia.org/wikipedia/en/9/91/12_angry_men.jpg'
    if rank_title == '72_Rosemary%27s_Baby_(film)':
        url = 'https://upload.wikimedia.org/wikipedia/en/e/ef/Rosemarys_baby_poster.jpg'
    if rank_title == '93_Harry_Potter_and_the_Deathly_Hallows_–_Part_2':
        url = 'https://upload.wikimedia.org/wikipedia/en/d/df/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2.jpg'
    else:
        continue
    title = rank_title[3:]
    df_list.append({'ranking': int(title_list.index(title) + 1),
                    'title': title,
                    'poster_url': url})
    r = requests.get(url)
    # Download movie poster image
    i = Image.open(BytesIO(r.content))
    image_file_format = url.split('.')[-1]
    i.save(folder_name + "/" + rank_title + '.' + image_file_format)

# %%
df = pd.DataFrame(df_list, columns = ['ranking', 'title', 'poster_url'])
df = df.sort_values('ranking').reset_index(drop=True)
df
# Out:
#     ranking                                          title  \
# 0         1                   The_Wizard_of_Oz_(1939_film)
# 1         4                                 Get_Out_(film)
# 2         5                             Mad_Max:_Fury_Road
# 3         8                         Inside_Out_(2015_film)
# 4         9                                  The_Godfather
# 5        11                     E.T._the_Extra-Terrestrial
# 6        12                            Modern_Times_(film)
# 7        14                            Singin'_in_the_Rain
# 8        16                              Casablanca_(film)
# 9        17                          Moonlight_(2016_film)
# 10       20                                      Nosferatu
# 11       21    Snow_White_and_the_Seven_Dwarfs_(1937_film)
# 12       25                          The_Battle_of_Algiers
# 13       26                            Dunkirk_(2017_film)
# 14       29                        12_Years_a_Slave_(film)
# 15       30                            Gravity_(2013_film)
# 16       31                        Sunset_Boulevard_(film)
# 17       33                               Spotlight_(film)
# 18       37                                   Selma_(film)
# 19       38                                    Taxi_Driver
# 20       39                                    Toy_Story_3
# 21       40                               Argo_(2012_film)
# 22       41                                    Toy_Story_2
# 23       42                                   The_Big_Sick
# 24       44                                       Zootopia
# 25       45                                  M_(1931_film)
# 26       46                       Wonder_Woman_(2017_film)
# 27       48                                   Alien_(film)
# 28       49                                Bicycle_Thieves
# 29       52                                 Up_(2009_film)
# 30       55                                   Logan_(film)
# 31       58                                 Arrival_(film)
# 32       59                                    Baby_Driver
# 33       62                   Star_Wars:_The_Force_Awakens
# 34       63                   Manchester_by_the_Sea_(film)
# 35       64                                Dr._Strangelove
# 36       67                         The_Dark_Knight_(film)
# 37       69                                   The_Babadook
# 38       73                                   Finding_Nemo
# 39       74                                Brooklyn_(film)
# 40       75                       The_Wrestler_(2008_film)
# 41       76                       The_39_Steps_(1935_film)
# 42       77                       L.A._Confidential_(film)
# 43       79                 The_Good,_the_Bad_and_the_Ugly
# 44       80                                        Skyfall
# 45       84                          Pinocchio_(1940_film)
# 46       85                    The_Jungle_Book_(2016_film)
# 47       86                              La_La_Land_(film)
# 48       87                               Star_Trek_(film)
# 49       89                                 Apocalypse_Now
# 50       93  Harry_Potter_and_the_Deathly_Hallows_–_Part_2
# 51       96                                    Man_on_Wire
# 52       97                                    Jaws_(film)
# 53       98                                      Toy_Story
# 54       99                          The_Godfather_Part_II
#
#                                            poster_url
# 0   https://upload.wikimedia.org/wikipedia/commons...
# 1   https://upload.wikimedia.org/wikipedia/en/a/a3...
# 2   https://upload.wikimedia.org/wikipedia/en/6/6e...
# 3   https://upload.wikimedia.org/wikipedia/en/0/0a...
# 4   https://upload.wikimedia.org/wikipedia/en/1/1c...
# 5   https://upload.wikimedia.org/wikipedia/en/6/66...
# 6   https://upload.wikimedia.org/wikipedia/commons...
# 7   https://upload.wikimedia.org/wikipedia/commons...
# 8   https://upload.wikimedia.org/wikipedia/commons...
# 9   https://upload.wikimedia.org/wikipedia/en/8/84...
# 10  https://upload.wikimedia.org/wikipedia/en/9/92...
# 11  https://upload.wikimedia.org/wikipedia/en/4/49...
# 12  https://upload.wikimedia.org/wikipedia/en/a/aa...
# 13  https://upload.wikimedia.org/wikipedia/en/1/15...
# 14  https://upload.wikimedia.org/wikipedia/en/5/5c...
# 15  https://upload.wikimedia.org/wikipedia/en/f/f6...
# 16  https://upload.wikimedia.org/wikipedia/commons...
# 17  https://upload.wikimedia.org/wikipedia/en/f/f3...
# 18  https://upload.wikimedia.org/wikipedia/en/8/8f...
# 19  https://upload.wikimedia.org/wikipedia/en/3/33...
# 20  https://upload.wikimedia.org/wikipedia/en/6/69...
# 21  https://upload.wikimedia.org/wikipedia/en/e/e1...
# 22  https://upload.wikimedia.org/wikipedia/en/c/c0...
# 23  https://upload.wikimedia.org/wikipedia/en/6/69...
# 24  https://upload.wikimedia.org/wikipedia/en/9/96...
# 25  https://upload.wikimedia.org/wikipedia/en/a/ab...
# 26  https://upload.wikimedia.org/wikipedia/en/b/b0...
# 27  https://upload.wikimedia.org/wikipedia/en/c/c3...
# 28  https://upload.wikimedia.org/wikipedia/en/2/20...
# 29  https://upload.wikimedia.org/wikipedia/en/0/05...
# 30  https://upload.wikimedia.org/wikipedia/en/3/37...
# 31  https://upload.wikimedia.org/wikipedia/en/d/df...
# 32  https://upload.wikimedia.org/wikipedia/en/8/8e...
# 33  https://upload.wikimedia.org/wikipedia/en/a/a2...
# 34  https://upload.wikimedia.org/wikipedia/en/d/de...
# 35  https://upload.wikimedia.org/wikipedia/en/e/e6...
# 36  https://upload.wikimedia.org/wikipedia/en/1/1c...
# 37  https://upload.wikimedia.org/wikipedia/en/d/d7...
# 38  https://upload.wikimedia.org/wikipedia/en/2/29...
# 39  https://upload.wikimedia.org/wikipedia/en/5/5b...
# 40  https://upload.wikimedia.org/wikipedia/en/3/3e...
# 41  https://upload.wikimedia.org/wikipedia/en/f/ff...
# 42  https://upload.wikimedia.org/wikipedia/en/d/d8...
# 43  https://upload.wikimedia.org/wikipedia/en/4/45...
# 44  https://upload.wikimedia.org/wikipedia/en/a/a7...
# 45  https://upload.wikimedia.org/wikipedia/en/b/ba...
# 46  https://upload.wikimedia.org/wikipedia/en/a/a4...
# 47  https://upload.wikimedia.org/wikipedia/en/a/ab...
# 48  https://upload.wikimedia.org/wikipedia/en/2/29...
# 49  https://upload.wikimedia.org/wikipedia/en/c/c2...
# 50  https://upload.wikimedia.org/wikipedia/en/d/df...
# 51  https://upload.wikimedia.org/wikipedia/en/5/54...
# 52  https://upload.wikimedia.org/wikipedia/en/e/eb...
# 53  https://upload.wikimedia.org/wikipedia/en/1/13...
# 54  https://upload.wikimedia.org/wikipedia/en/0/03...
